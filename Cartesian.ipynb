# %%
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

# %%
figsize=(20, 4)

# %%
fig = plt.figure(figsize=figsize)

# %%
p1 = [[4, 5], [-2, 6]]

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ax.scatter(p1[0], p1[1])

# %%
ax.scatter(p1[1], p1[0])

# %%
ax.grid(b=True, which='major')

# %%
fig

# %% [markdown]
# * [stack](https://stackoverflow.com/questions/13430231/how-i-can-get-cartesian-coordinate-system-in-matplotlib)

# %% [markdown]
# <pre>
# from pylab import *
# import matplotlib.pyplot as plt
#
# x = [0,2,-3,-1.5]
# y = [0,3,1,-2.5]
# color=['m','g','r','b']
#
# fig = plt.figure()
# ax = fig.add_subplot(111)
#
# scatter(x,y, s=100 ,marker='o', c=color)
#
# [ plot( [dot_x,dot_x] ,[0,dot_y], '-', linewidth = 3 ) for dot_x,dot_y in zip(x,y) ]
# [ plot( [0,dot_x] ,[dot_y,dot_y], '-', linewidth = 3 ) for dot_x,dot_y in zip(x,y) ]
#
# left,right = ax.get_xlim()
# low,high = ax.get_ylim()
# arrow( left, 0, right -left, 0, length_includes_head = True, head_width = 0.15 )
# arrow( 0, low, 0, high-low, length_includes_head = True, head_width = 0.15 )
#
# grid()
#
# show()
# </pre>

# %%
import pplot as ppt

# %%
from importlib import reload
reload(ppt)
# Out:
# <module 'pplot' from '/Users/paulm/code/pplot/pplot.py'>

# %%
r1 = [(1, 2), (4, 2), (1, 5), (4, 5)]
r2 = [(1, 8), (3, 8), (1, 5.5), (3, 5.5)]

# %%
ppt.rects(r1, r2)

# %%
rX = [(1, 8), (4, 8), (1, 3), (4, 3)]
rotrX = [(-8, 1), (-8, 4), (-3, 1), (-3, 4)]

# %%
ppt.rects(rX, rotrX)

# %%
rX = [(1, 8), (4, 8), (1, 3), (4, 3)]
rotrX = [(-0.404378, 8.05211), (2.55005, 8.57305), (0.463863, 3.12807), (3.41829, 3.64902)]

# %%
ppt.rects(rX, rotrX)

# %%
rX = [(1, 8), (4, 8), (1, 3), (4, 3)]
rotrX = [(-4.94975, 6.36396), (-2.82843, 8.48528), (-1.41421, 2.82843), (0.707107, 4.94975)]

# %%
ppt.rects(rX, rotrX)
